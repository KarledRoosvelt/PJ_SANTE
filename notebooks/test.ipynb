# %%
import pandas as pd

# %%
data = pd.read_csv('AI_in_Healthcare_Dataset.csv')

# %%
data.head()
# Out:
#    Patient_ID  Age  Gender  Blood_Pressure  Heart_Rate  Temperature  \
# 0           1   62  Female      102.349134   79.827209    98.912361
# 1           2   65    Male      137.760933   72.817449    98.912508
# 2           3   82    Male       97.618564   57.135424    99.189728
# 3           4   85    Male      121.743752   67.355838    96.033487
# 4           5   85    Male      129.530450   64.849416    99.077675
#
#        Diagnosis    Medication  Treatment_Duration Insurance_Type  \
# 0   Hypertension       Statins                  24      Uninsured
# 1   Hypertension       Insulin                  29      Uninsured
# 2      Influenza  Chemotherapy                  15        Private
# 3  Heart Disease  Chemotherapy                   5        Private
# 4  Heart Disease       Insulin                  10        Private
#
#    Doctor_Name        Hospital_Name  Lab_Test_Results X-ray_Results  \
# 0    Dr. Brown  Children's Hospital        114.906151      Abnormal
# ...

# %%
data.shape
# Out:
# (5000, 20)

# %%
data["Hospital_Name"].unique()
# Out:
# array(["Children's Hospital", 'Healthcare Clinic', 'City Medical Center',
#        'Regional Hospital', 'General Hospital'], dtype=object)

# %%
data["Doctor_Name"].unique()
# Out:
# array(['Dr. Brown', 'Dr. Wang', 'Dr. Johnson', 'Dr. Smith', 'Dr. Lee'],
#       dtype=object)

# %%
data["Diagnosis"].unique()
# Out:
# array(['Hypertension', 'Influenza', 'Heart Disease', 'Cancer', 'Diabetes'],
#       dtype=object)

# %%
data["Medication"].unique()
# Out:
# array(['Statins', 'Insulin', 'Chemotherapy', 'Aspirin', 'Antibiotics'],
#       dtype=object)

# %%
data["Surgery_Type"].unique()
# Out:
# array(['Appendectomy', 'Knee Replacement', 'Gallbladder Removal',
#        'Cataract Surgery', 'Angioplasty'], dtype=object)

# %%
data.dtypes
# Out:
# Patient_ID                   int64
# Age                          int64
# Gender                      object
# Blood_Pressure             float64
# Heart_Rate                 float64
# Temperature                float64
# Diagnosis                   object
# Medication                  object
# Treatment_Duration           int64
# Insurance_Type              object
# Doctor_Name                 object
# Hospital_Name               object
# Lab_Test_Results           float64
# X-ray_Results               object
# Surgery_Type                object
# Recovery_Time                int64
# Allergies                   object
# Family_History              object
# Patient_Satisfaction         int64
# AI_Diagnosis_Confidence    float64
# dtype: object

# %%
data["X-ray_Results"].unique()
# Out:
# array(['Abnormal', 'Normal'], dtype=object)

# %%
data["Allergies"].unique()
# Out:
# array(['Latex', 'Shellfish', nan, 'Penicillin', 'Peanuts'], dtype=object)
